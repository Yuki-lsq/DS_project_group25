# %% [markdown]
# # Load Data

# %%
import os
import pandas as pd

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# ## Survey Answer Meaning
#
#                                0  Never
#                                1  Often
#                                2  Sometimes
#                                3  Yes, but not in the last 12 months
#                                4  Yes, but frequency in last 12 months missing
#                            (m) 9  Missing
#                           (na)    Not applicable
#
# Logic:
# 1. Technically, the meanings of 'missing' will be same as the 'na' value, here we assume they are together (tbh there is no value '9' in all the attribute columns)
# 2. Here, we are still using the 'smaller means more serious'. The computational method will be: SUM(all attribute values) / # not na or 9 or 0 col = avg of the valid answer
# 3. This algo should apply for each type of violence and the overall one
# ??: the formula should consider the number of vaild answer

# %% [markdown]
# # Data Cleaning

# %%
emotional_list = ['d101a', 'd101b', 'd101c', 'd101d', 'd101e', 'd101f', 'd103a', 'd103b']
physical_list = ['d105a', 'd105b', 'd105c', 'd105d', 'd105e', 'd105f', 'd105g']
sexual_list = ['d105h', 'd105i', 'd105k']

# %%
attribute_lists = {
    'emotional': emotional_list,
    'physical': physical_list,
    'sexual': sexual_list
}

# %%
#new
def data_cleaning(raw_data, attribute_lists):
    # Read the raw CSV dataset
    whole_data = raw_data

    # Convert column names to lowercase
    whole_data.columns = whole_data.columns.str.lower()


    # Drop the NA rows from the main dataset
    cleaned_data = whole_data.dropna(how='all')

    # Separate rows where all values in the attribute lists are NA
    attribute_columns = [col for cols in attribute_lists.values() for col in cols if col in cleaned_data.columns]
    attribute_data = cleaned_data[attribute_columns]
    all_na_rows = cleaned_data[attribute_data.isna().all(axis=1)]
    cleaned_violence_data = cleaned_data[~cleaned_data.index.isin(all_na_rows.index)]

    # Reset the index so that it can be tracked by ID later
    cleaned_violence_data = cleaned_violence_data.reset_index(drop=True)
    cleaned_violence_data['unique_id'] = cleaned_violence_data.index + 1

    # Reorder columns to have 'unique_id' first
    cols = ['unique_id'] + [col for col in cleaned_violence_data.columns if col != 'unique_id']
    cleaned_violence_data = cleaned_violence_data[cols]

    return cleaned_violence_data, all_na_rows

# %%
y_list=['d101a', 'd101b', 'd101c', 'd101d', 'd101e', 'd101f', 'd103a',
            'd103b','d105a', 'd105b', 'd105c', 'd105d', 'd105e', 'd105f', 'd105g',
            'd105h', 'd105i', 'd105k']

# %% [markdown]
# # Response Variable (y) Calculation

# %%
def compute_valid_and_sum(df, attribute_lists):
    # Initialize overall metrics
    df['overall_valid_count'] = 0
    df['overall_valid_sum'] = 0.0

    for name, columns in attribute_lists.items():
        existing_columns = [col for col in columns if col in df.columns]
        if not existing_columns:  # If no columns exist, set metrics to 0
            df[f'{name}_valid_count'] = 0
            df[f'{name}_valid_sum'] = 0.0
            df[f'{name}_avg'] = 0
        else:
            # Replace 0 and 9 with NaN to consider them as invalid
            valid_df = df[existing_columns].replace([0, 9], float('nan'))
            # Compute valid counts and sum for the attribute list
            df[f'{name}_valid_count'] = valid_df.notna().sum(axis=1)
            df[f'{name}_valid_sum'] = valid_df.sum(axis=1)
            # Calculate average, handling division by zero by filling NaN with 0
            df[f'{name}_avg'] = (df[f'{name}_valid_sum'] / df[f'{name}_valid_count']).fillna(0)

        # Update the overall valid count and sum
        df['overall_valid_count'] += df[f'{name}_valid_count']
        df['overall_valid_sum'] += df[f'{name}_valid_sum']

    # Compute the overall average and handle division by zero
    df['overall_avg'] = (df['overall_valid_sum'] / df['overall_valid_count']).fillna(0)

    return df

# %% [markdown]
# # Metadata Mapping

# %%
y_list=['d101a', 'd101b', 'd101c', 'd101d', 'd101e', 'd101f', 'd103a',
            'd103b','d105a', 'd105b', 'd105c', 'd105d', 'd105e', 'd105f', 'd105g',
            'd105h', 'd105i', 'd105k']

emotional_list = ['d101a', 'd101b', 'd101c', 'd101d', 'd101e', 'd101f', 'd103a', 'd103b']
physical_list = ['d105a', 'd105b', 'd105c', 'd105d', 'd105e', 'd105f', 'd105g']
sexual_list = ['d105h', 'd105i', 'd105k']


attribute_lists = {
    'emotional': emotional_list,
    'physical': physical_list,
    'sexual': sexual_list
}

# %%
def metadata(metadata_path):
    try:
        metadata = pd.read_csv(metadata_path, encoding='utf-8')
    except UnicodeDecodeError:
        # Try a different encoding if UTF-8 does not work
        metadata = pd.read_csv(metadata_path, encoding='ISO-8859-1')
    metadata['Item Name'] = metadata['Item Name'].apply(lambda x: x.lower() if isinstance(x, str) else x)
    return metadata

# %%
new_des=['Never','Yes, but not in the last 12 months','Sometimes','Often']

# %%
def apply_mappings(data, mappings):

    for column, mapping in mappings.items():
        if column in data.columns:
            # Convert mapping keys from string to appropriate type, if possible
            try:

                mapping_int_keys = {int(k): v for k, v in mapping.items()}

            except ValueError:
                # If conversion fails, use the mapping as is
                mapping_int_keys = mapping

            # Apply the mapping to the DataFrame column using map on the specific series
            data[column] = data[column].map(mapping_int_keys).fillna(data[column])

    return data

# %%
main_folder = "E:/all_asian_data(90%)_test/Individual"

dta_files = []


for root, dirs, files in os.walk(main_folder):
    dirs.sort(reverse=True)
    files.sort(reverse=True)
    for file in files:
        if file.endswith('on.csv'):
            meta_path = os.path.join(root, file)
            try:
                metadata = pd.read_csv(meta_path, encoding='utf-8')
            except UnicodeDecodeError:
             # Try a different encoding if UTF-8 does not work
                metadata = pd.read_csv(meta_path, encoding='ISO-8859-1')
            if len(metadata)==0:
                break  
            metadata['Item Name'] = metadata['Item Name'].apply(lambda x: x.lower() if isinstance(x, str) else x)
            try:
                for i in y_list:
                    indices = metadata[metadata['Item Name'] == i].index
                    for num in range(4):
                        metadata.loc[indices[num+1], 'Description'] = new_des[num]
            except IndexError as e:
                break
            
            mappings = {}
            for item in metadata['Item Name'].unique():
                mappings[item] = dict(zip(metadata[metadata['Item Name'] == item]['Code'],
                                            metadata[metadata['Item Name'] == item]['Description']))
            print(meta_path) 
        if file.endswith(').csv'):
            file_path = os.path.join(root, file)
            print(file_path)
            raw_data=pd.read_csv(file_path)
            clean_data, all_na_rows = data_cleaning(raw_data, attribute_lists)
            clean = clean_data.loc[:, ~clean_data.columns.duplicated()]
            if len(clean)==0:
                break
            clean[y_list]=clean[y_list].replace({0:1,1:4,2:3,3:2})
            result = compute_valid_and_sum(clean, attribute_lists)
            df = apply_mappings(result, mappings)
            for i in df.columns:
                try:
                    name=list(metadata[metadata['Item Name']==i]['Item Label'])[0]
                    df = df.rename(columns={i: name})
                except IndexError as e:
                    print('')
            
            if len(df)!=0:               
                dta_files.append(df)
# Out:
# E:/all_asian_data(90%)_test/Individual\Philippines Standard DHS 2022\Philippines Standard DHS 2022_variable_description.csv
# E:/all_asian_data(90%)_test/Individual\Philippines Standard DHS 2022\Philippines Standard DHS 2022(90).csv
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])
# C:\Users\wangc\AppData\Local\Temp\ipykernel_38792\3656317338.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].map(mapping_int_keys).fillna(data[column])

# %%
num=0
for i in dta_files:
    num+=len(i)
num
# Out:
# 25313

# %%
dta_files = [df.T.drop_duplicates().T for df in dta_files]

# %%
list(dta_files[1].columns)
# Out:
# ['unique_id',
#  'Case Identification',
#  'Country code and phase',
#  'Cluster number',
#  'Household number',
#  "Respondent's line number",
#  "Women's individual sample weight (6 decimals)",
#  'Month of interview',
#  'Year of interview',
#  'Date of interview (CMC)',
#  'Date of interview Century Day Code (CDC)',
#  "Respondent's month of birth",
#  "Respondent's year of birth",
#  'Date of birth (CMC)',
#  "Respondent's current age",
#  'Age in 5-year groups',
#  'Completeness of age information',
#  'Result of individual interview',
#  'Day of interview',
#  'CMC start of calendar',
#  'Row of month of interview',
#  'Length of calendar',
#  'Number of calendar columns',
#  'Ever-married sample',
#  'Sample strata for sampling errors',
#  'Province',
#  'Type of place of residence',
#  'Number of visits',
#  'Interviewer identification',
#  'Field supervisor',
#  'Line number of husband',
#  'Cluster altitude in meters',
#  'Household selected for hemoglobin',
#  'Selected for Domestic Violence module',
#  'Language of questionnaire',
#  'Language of interview',
#  'Native language of respondent',
#  'Translator used',
#  'Team number',
#  'Years lived in place of residence',
#  'Type of place of previous residence',
#  'Region of previous residence',
#  'Highest educational level',
#  'Highest year of education',
#  'Source of drinking water',
#  'Time to get to water source',
#  'Type of toilet facility',
#  'Household has: electricity',
#  'Household has: radio',
#  'Household has: television',
#  'Household has: refrigerator',
#  'Household has: bicycle/Rickshaw',
#  'Household has: motorcycle/scooter',
#  'Household has: car/truck/tractor',
#  'Main floor material',
#  'Main wall material',
#  'Main roof material',
#  'Religion',
#  'Ethnicity',
#  'Education in single years',
#  'Usual resident or visitor',
#  'Number of household members (listed)',
#  'Number of children 5 and under in household (de jure)',
#  'Number of eligible women in household (de facto)',
#  'De jure province of residence',
#  'De jure type of place of residence',
#  'Educational attainment',
#  'Relationship to household head',
#  'Sex of household head',
#  'Age of household head',
#  'Household has: telephone (land-line)',
#  'All woman factor - total',
#  'Literacy',
#  'Frequency of reading newspaper or magazine',
#  'Frequency of listening to radio',
#  'Frequency of watching television',
#  'Toilet facilities shared with other households',
#  'Type of cooking fuel',
#  'Owns a mobile telephone',
#  'Last 12 months use mobile telephone for financial transactions',
#  "Is respondent's mobile phone a smart phone",
#  'Has an account in a bank or other financial institution',
#  'Use of internet',
#  'Frequency of using internet last month',
#  'Respondent state of birth',
#  'Month move to current place of residence',
#  'Year move to current place of residence',
#  'Reason for moving to current place of residence',
#  'Self reported health status',
#  'Money put/taken from bank account last 12 months',
#  'Wealth index combined',
#  'Wealth index factor score combined (5 decimals)',
#  'Wealth index for urban/rural',
#  'Wealth index factor score for urban/rural (5 decimals)',
#  'bidx_01',
#  'bidx_02',
#  'bidx_03',
#  'bidx_04',
#  'bidxp_01',
#  'bidxp_02',
#  'bidxp_03',
#  'bidxp_04',
#  'bord_01',
#  'bord_02',
#  'bord_03',
#  'bord_04',
#  'b0_01',
#  'b0_02',
#  'b0_03',
#  'b0_04',
#  'b1_01',
#  'b1_02',
#  'b1_03',
#  'b1_04',
#  'b2_01',
#  'b2_02',
#  'b2_03',
#  'b2_04',
#  'b3_01',
#  'b3_02',
#  'b3_03',
#  'b3_04',
#  'b4_01',
#  'b4_02',
#  'b4_03',
#  'b4_04',
#  'b5_01',
#  'b5_02',
#  'b5_03',
#  'b5_04',
#  'b8_01',
#  'b8_02',
#  'b8_03',
#  'b8_04',
#  'b9_01',
#  'b9_02',
#  'b9_03',
#  'b9_04',
#  'b10_01',
#  'b10_02',
#  'b10_03',
#  'b10_04',
#  'b11_01',
#  'b11_02',
#  'b11_03',
#  'b12_02',
#  'b12_03',
#  'b12_04',
#  'b15_01',
#  'b15_02',
#  'b15_03',
#  'b15_04',
#  'b16_01',
#  'b16_02',
#  'b16_03',
#  'b16_04',
#  'b17_01',
#  'b17_02',
#  'b17_03',
#  'b17_04',
#  'b18_01',
#  'b18_02',
#  'b18_03',
#  'b18_04',
#  'b19_01',
#  'b19_02',
#  'b19_03',
#  'b19_04',
#  'b20_01',
#  'b20_02',
#  'b20_03',
#  'b20_04',
#  'b21_01',
#  'b21_02',
#  'b21_03',
#  'b21_04',
#  'pidx_01',
#  'pidx_02',
#  'pidx_03',
#  'pidx_04',
#  'pidx_05',
#  'pidxb_01',
#  'pidxb_02',
#  'pidxb_03',
#  'pidxb_04',
#  'pidxb_05',
#  'pord_01',
#  'pord_02',
#  'pord_03',
#  'pord_04',
#  'pord_05',
#  'p0_01',
#  'p0_02',
#  'p0_03',
#  'p0_04',
#  'p0_05',
#  'p1_01',
#  'p1_02',
#  'p1_03',
#  'p1_04',
#  'p1_05',
#  'p2_01',
#  'p2_02',
#  'p2_03',
#  'p2_04',
#  'p2_05',
#  'p3_01',
#  'p3_02',
#  'p3_03',
#  'p3_04',
#  'p3_05',
#  'p4_01',
#  'p4_02',
#  'p4_03',
#  'p4_04',
#  'p4_05',
#  'p5_01',
#  'p5_02',
#  'p5_03',
#  'p5_04',
#  'p5_05',
#  'p8_01',
#  'p8_02',
#  'p8_03',
#  'p8_04',
#  'p9_01',
#  'p9_02',
#  'p9_03',
#  'p9_04',
#  'p10_01',
#  'p10_02',
#  'p10_03',
#  'p10_04',
#  'p10_05',
#  'p11_01',
#  'p11_02',
#  'p11_03',
#  'p11_04',
#  'p12_02',
#  'p12_03',
#  'p12_04',
#  'p12_05',
#  'p15_01',
#  'p15_02',
#  'p15_03',
#  'p15_04',
#  'p15_05',
#  'p16_01',
#  'p16_02',
#  'p16_03',
#  'p16_04',
#  'p17_01',
#  'p17_02',
#  'p17_03',
#  'p17_04',
#  'p17_05',
#  'p18_01',
#  'p18_02',
#  'p18_03',
#  'p18_04',
#  'p18_05',
#  'p19_01',
#  'p19_02',
#  'p19_03',
#  'p19_04',
#  'p19_05',
#  'p20_01',
#  'p20_02',
#  'p20_03',
#  'p20_04',
#  'p20_05',
#  'p21_01',
#  'p21_02',
#  'p21_03',
#  'p21_04',
#  'p21_05',
#  'p30_01',
#  'p30_02',
#  'p30_03',
#  'p30_04',
#  'p30_05',
#  'p32_03',
#  'p32_04',
#  'Total children ever born',
#  'Sons at home',
#  'Daughters at home',
#  'Sons elsewhere',
#  'Daughters elsewhere',
#  'Sons who have died',
#  'Daughters who have died',
#  'Births in last five years',
#  'Births in past year',
#  'Births in month of interview',
#  'Date of first birth (CMC)',
#  'Age of respondent at 1st birth',
#  'Currently pregnant',
#  'Time since last menstrual period',
#  'Menstruated in last six weeks',
#  'Knowledge of ovulatory cycle',
#  'Number of living children',
#  'Living children + current pregnancy',
#  'Living children + current pregnancy (grouped)',
#  'Marriage to first birth interval (months)',
#  'Time since last period (comp) (months)',
#  'Flag for last period',
#  'Ever had a terminated pregnancy',
#  'Month pregnancy ended',
#  'Year pregnancy ended',
#  'CMC pregnancy ended',
#  'Completeness of last termination information',
#  'Months when pregnancy ended',
#  'Other such pregnancies',
#  'Index last child prior to maternity-health (calendar)',
#  'Birth between last and interview',
#  'Births in last three years',
#  'Pregnancies terminated before calendar beginning',
#  'Month of last termination prior to calendar',
#  'Year of last termination prior to calendar',
#  'CMC termination ended prior to calendar',
#  'Completeness of last termination date prior to calendar',
#  'Can women get pregnant after birth and before period',
#  'Pregnancy losses',
#  'Entries in pregnancy history',
#  'Collection of menstrual blood: reusable sanitary pads',
#  'Collection of menstrual blood: disposable sanitary pads',
#  'Collection of menstrual blood: tampons',
#  'Collection of menstrual blood: menstrual cup',
#  'Collection of menstrual blood: cloth',
#  'Collection of menstrual blood: toilet paper',
#  'Collection of menstrual blood: cotton wool',
#  'Collection of menstrual blood: underwear only',
#  'Collection of menstrual blood: other',
#  'Collection of menstrual blood: nothing',
#  'Able to change in privacy during last menstrual cycle',
#  'Age at first menstrual period',
#  'Knowledge of any method',
#  'Ever used anything or tried to delay or avoid getting pregnant',
#  'v304a_01',
#  'v304a_10',
#  'v304_01',
#  'v304_02',
#  'v304_03',
#  'v304_04',
#  'v304_05',
#  'v304_06',
#  'v304_07',
#  'v304_08',
#  'v304_09',
#  'v304_10',
#  'v304_11',
#  'v304_13',
#  'v304_16',
#  'v304_17',
#  'v304_18',
#  'v307_01',
#  'v307_02',
#  'v307_03',
#  'v307_05',
#  'v307_06',
#  'v307_07',
#  'v307_08',
#  'v307_09',
#  'v307_11',
#  'v307_13',
#  'v307_16',
#  'Current contraceptive method',
#  'Current use by method type',
#  'Month of start of use of method',
#  'Year of start of use of method',
#  'Date of start of use of method (CMC)',
#  'Completeness of information',
#  'Years since sterilization',
#  'Age at sterilization',
#  'Years since first union at sterilization',
#  'Years since current union at sterilization',
#  'Parity at sterilization',
#  'Last source for current users',
#  'Last source for users by type',
#  'Months of use of current method',
#  'Last method discontinued in last 5 years',
#  'Reason of last discontinuation',
#  'Pattern of use',
#  'Intention to use',
#  'Contraceptive use and intention',
#  'Wanted last child',
#  'Wanted last pregnancy',
#  'Source known for any method',
#  'Source known for any method',
#  'Heard family planning on radio last few months',
#  'Heard family planning on TV last few months',
#  'Heard family planning in newspaper/magazine last few months',
#  'Heard family planning by text messages on mobile phone',
#  'Seen about family planning on facebook, twitter, instagram, others',
#  'Seen about family planning on poster, brochure',
#  'Seen about family planning on outdoor sign, billboard',
#  'Heard family planning at community meetings events',
#  'Visited by fieldworker in last 12 months',
#  'Did fieldworker talk about family planning',
#  'Visited health facility last 12 months',
#  'At health facility, told of family planning',
#  'Source of family planning for non-users: no source',
#  'Source of family planning for non-users: any source',
#  'Told about side effects',
#  'Told how to deal with side effects',
#  'Told about other family planning methods',
#  'First source for current method',
#  'Reason not using: not married',
#  'Reason not using: not having sex',
#  'Reason not using: infrequent sex',
#  'Reason not using: menopausal/hysterectomy',
#  'Reason not using: subfecund/infecund',
#  'Reason not using: postpartum amenorrheic',
#  'Reason not using: breastfeeding',
#  'Reason not using: fatalistic',
#  'Reason not using: respondent opposed',
#  'Reason not using: husband/partner opposed',
#  'Reason not using: others opposed',
#  'Reason not using: religious prohibition',
#  'Reason not using: knows no method',
#  'Reason not using: other side effects',
#  'Reason not using: lack of access/too far',
#  'Reason not using: inconvenient to use',
#  "Reason not using: interferes with body's processes",
#  'Reason not using: preferred method not available',
#  'Reason not using: no method available',
#  'Reason not using: changes in menstrual bleeding',
#  'Reason not using: methods could cause infertility',
#  'Reason not using: other',
#  "Reason not using: don't know",
#  'Probe for respondent/partner sterilized',
#  'Used emergency contraception in past 12 months',
#  'Could switch method if wanted/needed',
#  'midx_1',
#  'midxp_1',
#  'm1_1',
#  'm2a_1',
#  'm2b_1',
#  'm2c_1',
#  'm2g_1',
#  'm2h_1',
#  'm2k_1',
#  'm2n_1',
#  'm3a_1',
#  'm3b_1',
#  'm3c_1',
#  'm3g_1',
#  'm3h_1',
#  'm3i_1',
#  'm3k_1',
#  'm3n_1',
#  'm4_1',
#  'm5_1',
#  'm6_1',
#  'm7_1',
#  'm8_1',
#  'm9_1',
#  'm10_1',
#  'm13_1',
#  'm13a_1',
#  'm14_1',
#  'm15_1',
#  'm17_1',
#  'm18_1',
#  'm19_1',
#  'm19a_1',
#  'm34_1',
#  'm38_1',
#  'm39a_1',
#  'm39_1',
#  'm42a_1',
#  'm42c_1',
#  'm42d_1',
#  'm42e_1',
#  'm42f_1',
#  'm42g_1',
#  'm42h_1',
#  'm42i_1',
#  'm42l_1',
#  'm42m_1',
#  'm42n_1',
#  'm45_1',
#  'm46_1',
#  'm55_1',
#  'm57a_1',
#  'm57b_1',
#  'm57e_1',
#  'm57f_1',
#  'm57g_1',
#  'm57h_1',
#  'm57i_1',
#  'm57j_1',
#  'm57k_1',
#  'm57m_1',
#  'm57n_1',
#  'm57o_1',
#  'm57p_1',
#  'm57nb_1',
#  'm57nc_1',
#  'm57nd_1',
#  'm57x_1',
#  'm60_1',
#  'm61_1',
#  'm62_1',
#  'm63_1',
#  'm64_1',
#  'm66_1',
#  'm70_1',
#  'm74_1',
#  'm75_1',
#  'm76_1',
#  'm77_1',
#  'm78a_1',
#  'm78b_1',
#  'm78c_1',
#  'm78d_1',
#  'm78e_1',
#  'm78f_1',
#  'm78g_1',
#  'm78h_1',
#  'm78i_1',
#  'm78m_1',
#  'm78n_1',
#  'm78o_1',
#  'm78p_1',
#  'm80_1',
#  'm81a_1',
#  'm81b_1',
#  'm81c_1',
#  'm81d_1',
#  'm81e_1',
#  'm81f_1',
#  'm81g_1',
#  'm81h_1',
#  'm81j_1',
#  'm81k_1',
#  'm81l_1',
#  'm81m_1',
#  'm81nb_1',
#  'm81nd_1',
#  'm81s_1',
#  'm81x_1',
#  'm82_1',
#  'mnb1_1',
#  'mnb6_1',
#  'mnb7a_1',
#  'mnb7b_1',
#  'mnb7c_1',
#  'mnb7d_1',
#  'mnb7e_1',
#  'mnb7x_1',
#  'mnb7z_1',
#  'mnb11_1',
#  'mnb12_1',
#  'mh17a_1',
#  'mh17b_1',
#  'mh17c_1',
#  'mh18a_1',
#  'mh18b_1',
#  'mh21a_1',
#  'mh21b_1',
#  'mh21c_1',
#  'mh21d_1',
#  'mh22a_1',
#  'mh22b_1',
#  'mh22c_1',
#  'mh22d_1',
#  'Line number of child used for questions on liquids and foods',
#  'Gave child plain water',
#  'Gave child fruit juice/fruit flavored drinks',
#  'Gave child tea or coffee/herbal drinks',
#  'Gave child tinned, powdered or fresh milk',
#  'Gave child baby formula',
#  'Gave child soup/clear broth',
#  'Gave child other liquid',
#  'Gave child yogurt as a drink - Lassi',
#  'Gave child chocolate flavored drinks (Horlicks, Bournvita, Viva)',
#  'Gave child sodas/malt/sports/energy drinks',
#  'Gave child any other vegetables',
#  'Gave child sausages, hot dogs, frankfurters, ham, bacon, salami, canned food',
#  'Gave child nuts, seeds',
#  'Gave child rice, paratha, naan, roti or other foods made from grains',
#  'Gave child plantains, potatoes, cassava, or other tubers',
#  'Gave child eggs',
#  'Gave child any other meat (beef, pork, lamb, chicken, etc)',
#  'Gave child pumpkin, carrots, squash (yellow or orange inside)',
#  'Gave child any dark green leafy vegetables',
#  'Gave child mangoes, papayas, other vitamin A fruits',
#  'Gave child any other fruits',
#  'Gave child liver, heart, other organs',
#  'Gave child fish or shellfish',
#  'Gave child food made from beans, peas, lentils',
#  'Gave child hard/soft cheese',
#  'Gave child any sweet food such as cake, biscuits, cookies, jeri/jalebi, mithai, ',
#  'Gave child other solid-semisolid food',
#  'Gave child chips, crisps, french fries, fried dough, instant noodles',
#  'Gave child yogurt',
#  'Gave child gundruk, braised-fenugreek greens, or broccoli - CS',
#  "Disposal of youngest child's stools when not using toilet",
#  'Last 6 months, health care provider advised what to feed to child',
#  'hidx_1',
#  'h1_1',
#  'h1a_1',
#  'h2_1',
#  'h2d_1',
#  'h2m_1',
#  'h2y_1',
#  'h3_1',
#  'h3d_1',
#  'h3m_1',
#  'h3y_1',
#  'h4_1',
#  'h4d_1',
#  'h4m_1',
#  'h4y_1',
#  'h5_1',
#  'h5d_1',
#  'h5m_1',
#  'h5y_1',
#  'h6_1',
#  'h6d_1',
#  'h6m_1',
#  'h6y_1',
#  'h7_1',
#  'h7d_1',
#  'h7m_1',
#  'h7y_1',
#  'h8_1',
#  'h8d_1',
#  'h8m_1',
#  'h8y_1',
#  'h9_1',
#  'h9a_1',
#  'h25d_1',
#  'h25m_1',
#  'h25y_1',
#  'h26_1',
#  'h33_1',
#  'h54_1',
#  'h54d_1',
#  'h54m_1',
#  'h54y_1',
#  'h55_1',
#  'h55d_1',
#  'h55m_1',
#  'h55y_1',
#  'h56_1',
#  'h57_1',
#  'h58_1',
#  'h60_1',
#  'h60d_1',
#  'h60m_1',
#  'h60y_1',
#  'h69_1',
#  'hidxa_1',
#  'h11_1',
#  'h22_1',
#  'h31_1',
#  'h31b_1',
#  'h34_1',
#  'h43_1',
#  'h70a_1',
#  'h70b_1',
#  'h70c_1',
#  'h80a_1',
#  'hw1_1',
#  'hw13_1',
#  'Last birth a caesarean section',
#  'Currently breastfeeding',
#  'Currently amenorrheic',
#  'Currently abstaining',
#  'Drank from bottle with nipple yesterday/last night',
#  'Entries in pregnancy and postnatal care roster',
#  'Entries in immunization roster',
#  'Entries in child health roster',
#  "Measurer's code",
#  'When child put to breast',
#  'Result of measurement - height/weight',
#  'Have mosquito bed net for sleeping (from household questionnaire)',
#  'Smokes cigarettes',
#  'Smokes pipe full of tobacco/Sulpha/Chilim',
#  'Chews tobacco',
#  'Snuffs by nose',
#  'Smokes cigars/Bidi',
#  'Smokes water pipe',
#  'Snuff by mouth',
#  'Chews betel quid with tobacco',
#  'Smokes/uses other',
#  'Does not use cigarettes and tobacco',
#  'Frequency smokes cigarettes',
#  'Frequency currently uses other type of tobacco',
#  'Getting medical help for self: getting permission to go',
#  'Getting medical help for self: getting money needed for treatment',
#  'Getting medical help for self: distance to health facility',
#  'Getting medical help for self: not wanting to go alone',
#  'Record for Last Birth',
#  'Woman had any other liquid',
#  'Woman had sodas/malt/sports/energy drinks',
#  'Woman had fruit juice, fruit-flavored drinks',
#  'Woman had other vegetables',
#  'Woman had sausages, hot dogs, frankfurters, ham, bacon, salami, canned food',
#  'Woman had nuts, seeds',
#  'Woman had porridge, bread, rice, noodles, pasta',
#  'Woman had plantains, white potatoes, yams, manioc cassava, or other tubers',
#  'Woman had eggs',
#  'Woman had any other meat (beef, pork, lamb, chicken, etc)',
#  'Woman had pumpkin, carrots, squash, sweet potatoes (yellow or orange inside)',
#  'Woman had any dark green leafy vegetables',
#  'Woman had mangoes, papayas, other vitamin A fruits',
#  'Woman had any other fruits',
#  'Woman had liver, heart, other organs',
#  'Woman had fish or shellfish',
#  'Woman had food made from beans, peas, lentils',
#  'Woman had cheese, yogurt, other milk products',
#  'Woman had sweet foods, cakes, biscuits, cookies, jeri/jalebi, mithai, toffees, i',
#  'Woman had any other food',
#  'Woman had chips, crisps, french fries, fried dough, instant noodles',
#  'Woman had sweetened tea, coffee or herbal drinks',
#  'Woman had gundruk, braised greens, fenugreek greens, or broccoli - CS',
#  'Covered by health insurance',
#  'Health insurance type: government health insurance',
#  'Health insurance type: provided by employer',
#  'Health insurance type: social security',
#  'Health insurance type: private/commercially purchased',
#  'Health insurance type: other',
#  'Minutes to nearest healthcare facility',
#  'Mode of transportation to nearest healthcare facility',
#  'Breasts examined for cancer by health care provider',
#  'Ever tested for cervical cancer by health care provider',
#  'Number of days respondent drank alcoholic drinks in the past month',
#  'Number of alcoholic drinks per day',
#  'Current marital status',
#  'Currently/formerly/never in union',
#  'Number of unions',
#  'Currently residing with husband/partner',
#  'Number of other wives',
#  'Month of first cohabitation',
#  'Year of first cohabitation',
#  'Date of first cohabitation (CMC)',
#  'Completeness of date information in V509',
#  'Age at first cohabitation',
#  'Years since first cohabitation',
#  'Cohabitation duration (grouped)',
#  'Age at first sex',
#  'Time since last sex',
#  'Time since last sex (in days)',
#  'Time since last sex (in months)',
#  'Flag for V529',
#  'Age at first sex (imputed)',
#  'Flag for V531',
#  'Ever been married or in union',
#  'Recent sexual activity',
#  'Months of abstinence',
#  'Has a marriage certificate for current marriage/union',
#  'Current marriage ever registered with civil authority',
#  'Fertility preference',
#  'Preferred waiting time for birth of a/another child',
#  'Preferred waiting time for birth of a/another child (grouped)',
#  'Desire for more children',
#  'Ideal number of children',
#  'Ideal number of children (grouped)',
#  'Time for future birth',
#  "Husband's desire for children",
#  'Exposure',
#  'Unmet need',
#  'Exposure (definition 2)',
#  'Unmet need (definition 2)',
#  'Exposure to need for contraception (definition 3)',
#  'Unmet need for contraception (definition 3)',
#  'Ideal number of boys',
#  'Ideal number of girls',
#  'Ideal number of either sex',
#  'Decision maker for using contraception',
#  'Reason for not having sex: husband has other women',
#  "Respondent opinion compared to husband's on use of contraception",
#  'Husband or family member pressured respondent to become pregnant',
#  "Husband/partner's education level",
#  "Husband/partner's highest year of education (at level in V701)",
#  "Husband/partner's occupation",
#  'Husband/partner worked in last 7 days/12 months',
#  "Husband/partner's occupation (grouped)",
#  'Respondent currently working',
#  'Respondent has a job, but currently absent',
#  "Husband/partner's total number of years of education",
#  "Respondent's occupation",
#  "Respondent's occupation (grouped)",
#  'Respondent works for family, others, self',
#  "Husband/partner's educational attainment",
#  "Husband/partner's age",
#  'Respondent worked in last 12 months',
#  'Respondent employed all year/seasonal',
#  "Person who usually decides how to spend respondent's earnings",
#  "Type of earnings from respondent's work",
#  "Person who usually decides on: respondent's health care",
#  'Person who usually decides on: large household purchases',
#  'Person who usually decides on: visits to family or relatives',
#  'Person who usually decides on: what to do with money husband earns',
#  'Beating justified if wife goes out without telling husband',
#  'Beating justified if wife neglects the children',
#  'Beating justified if wife argues with husband',
#  'Beating justified if wife refuses to have sex with husband',
#  'Beating justified if wife burns the food',
#  'Owns a house alone or jointly',
#  'Owns land alone or jointly',
#  'Title deed on land own by respondent',
#  'Respondent earns more than husband/partner',
#  'Ever heard of a Sexually Transmitted Infection (STI)',
#  'Ever heard of AIDS',
#  'Reduce risk of getting HIV: always use condoms during sex',
#  'Reduce risk of getting HIV: have 1 sex partner only, who has no other partners',
#  'Can get HIV from mosquito bites',
#  'Can get HIV by sharing food with person who has AIDS',
#  'A healthy looking person can have HIV',
#  'Condom used during last sex with most recent partner',
#  'Had any STI in last 12 months',
#  'Had genital sore/ulcer in last 12 months',
#  'Had genital discharge in last 12 months',
#  'Number of sex partners, excluding spouse, in last 12 months',
#  'Number of sex partners, including spouse, in last 12 months',
#  'Relationship with most recent sex partner',
#  'HIV transmitted during pregnancy',
#  'HIV transmitted during delivery',
#  'HIV transmitted by breastfeeding',
#  'Ever been tested for HIV',
#  'Heard about other STIs',
#  'Used a method at last sexual intercourse',
#  'Method used last sexual intercourse: female sterilization',
#  'Method used last sexual intercourse: male sterilization',
#  'Method used last sexual intercourse: IUD',
#  'Method used last sexual intercourse: injectables',
#  'Method used last sexual intercourse: implants',
#  'Method used last sexual intercourse: pill',
#  'Method used last sexual intercourse: condom',
#  'Method used last sexual intercourse: emergency contraception',
#  'Method used last sexual intercourse: standard days method',
#  'Method used last sexual intercourse: lactational amenorrhea',
#  'Method used last sexual intercourse: rhythm',
#  'Method used last sexual intercourse: withdrawal',
#  'Wife justified asking husband to use condom if he has STI',
#  'Drugs to avoid HIV transmission to baby during pregnancy',
#  'Would buy vegetables from vendor with HIV',
#  'Total lifetime number of sex partners',
#  'Heard of ARVs to treat HIV',
#  'Tested for HIV as part of antenatal visit',
#  'Respondent can refuse sex',
#  'Respondent can ask partner to use a condom',
#  'Knowledge and use of HIV test kits',
#  'Children with HIV should be allowed to attend school with children without HIV',
#  'Time interview started (hhmm - 24 hour clock)',
#  'Time interview ended (hhmm - 24 hour clock)',
#  'Length of interview in minutes',
#  "Presence of children < 10 for 'Wife beating justified' questions",
#  "Presence of husband for 'Wife beating justified' questions",
#  "Presence of other males for 'Wife beating justified' questions",
#  "Presence of other females for 'Wife beating justified' questions",
#  'Presence of children < 10 during sexual activity section',
#  'Presence of male adults during sexual activity section',
#  'Presence of female adults during sexual activity section',
#  'Calendar column number',
#  'Calendar',
#  'Calendar column number',
#  'Calendar',
#  'Weight for Domestic Violence (6 decimals)',
#  "Number of control issues answered 'Yes' (D101x = 1)",
#  'Ever been insulted or made to feel bad by husband/partner',
#  'Experienced any emotional violence (D103x series)',
#  'Ever had arm twisted or hair pulled by husband/partner',
#  'Experienced any less severe violence (D105A-C,J) by husband/partner',
#  'Experienced any severe violence (D105D-F) by husband/partner',
#  'Experienced any sexual violence (D105H-I,K) by husband/partner',
#  "Experienced any of listed husband/partner's actions (D110x series)",
#  'Respondent ever physically hurt husband/partner when he was not hurting her',
#  'Husband/partner drinks alcohol',
#  'Frequency of husband/partner being drunk',
#  'Mother: Person who has ever physically hurt respondent',
#  'Father: Person who has ever physically hurt respondent',
#  'Daughter/Son: Person who has ever physically hurt respondent',
#  'Sister/brother: Person who has ever physically hurt respondent',
#  'Other relative: Person who has ever physically hurt respondent',
#  'Former boyfriend: Person who has ever physically hurt respondent',
#  'Mother-in-law: Person who has ever physically hurt respondent',
#  'Father-in-law: Person who has ever physically hurt respondent',
#  'Other in-law: Person who has ever physically hurt respondent',
#  'Employer: Person who has ever physically hurt respondent',
#  'Other: Person who has ever physically hurt respondent',
#  'No person other than husband/partner ever physically hurt respondent',
#  'Schoolmate/classmate: Person who has ever physically hurt respondent',
#  'Police: Person who has ever physically hurt respondent',
#  'Husband/partner: Person who hurt respondent during a pregnancy',
#  'Mother: Person who hurt respondent during a pregnancy',
#  'Sister/brother: Person who hurt respondent during a pregnancy',
#  'Other relative: Person who hurt respondent during a pregnancy',
#  'Former husband/partner: Person who hurt respondent during a pregnancy',
#  'Mother-in-law: Person who hurt respondent during a pregnancy',
#  'Father-in-law: Person who hurt respondent during a pregnancy',
#  'Other in-law: Person who hurt respondent during a pregnancy',
#  'Employer: Person who hurt respondent during a pregnancy',
#  'Other: Person who hurt respondent during a pregnancy',
#  'Respondent was not hurt by anyone during a pregnancy',
#  "Respondent's father ever beat her mother",
#  "Interview interrupted: husband's presence",
#  "Interview interrupted: other adult male's presence",
#  "Interview interrupted: adult female's presence",
#  'Ever forced to perform unwanted sexual acts',
#  'Respondent afraid of husband/partner most of the time, sometimes or never',
#  'Previous husband: ever hit, slap, kick or physically hurt respondent',
#  'Previous husband: physically forced to have sex or to perform sexual acts',
#  'Previous husband: humiliate, threaten to hurt, insult or make feel bad',
#  'Last 2 weeks: feeling nervous, anxious, on edge',
#  'Last 2 weeks: not able to stop/control worrying',
#  'Last 2 weeks: worrying about things',
#  'Last 2 weeks: trouble relaxing',
#  'Last 2 weeks: restless and hard to sit still',
#  'Last 2 weeks: become easily annoyed/irritable',
#  'Last 2 weeks: feeling afraid as something awful might happen',
#  'Last 2 weeks: little interest/pleasure in doing things',
#  'Last 2 weeks: feeling down, depressed or hopeless',
#  'Last 2 weeks: trouble falling asleep or sleeping too much',
#  'Last 2 weeks: feeling tired or having little energy',
#  'Last 2 weeks: poor appetite or overeating',
#  'Last 2 weeks: feeling bad about yourself, you are a failure or let yourself or f',
#  'Last 2 weeks: trouble concentrating in reading or watching TV',
#  'Last 2 weeks: moving/speaking slowly or moving around a lot more than usual',
#  'Last 2 weeks: thoughts of better off dead or hurting yourself',
#  'Ever tried to seek help for the things you experienced',
#  'Person sought help from: doctor/medical personnel',
#  'Person sought help from: social service organization',
#  'Person sought help from: community health worker/fieldworker',
#  'Person sought help from: religious leader',
#  'Person sought help from: current/former spouse/partner',
#  'Person sought help from: other family member',
#  'Person sought help from: friend',
#  'Person sought help from: neighbor',
#  'Ever been told by a doctor/health care worker you have: depression',
#  'Ever been told by a doctor/health care worker you have: anxiety',
#  'Last 2 weeks took medication prescribed by doctor/health worker for depression/a',
#  'PHQ score',
#  'Referral based on PHQ score',
#  'GAD score',
#  'Currently experience constant leakage of urine or stool from vagina during the d',
#  'Have ever experienced a problem of leakage of urine or stool from vagina',
#  'Have ever heard of the problem of leakage of urine or stool from vagina',
#  'Household eligible for blood pressure measurement',
#  'Ecological region',
#  'District',
#  'Ever attended school - CS',
#  'Ever participated in literacy program - CS',
#  'Highest grade completed - CS',
#  'Highest educational level - CS',
#  'Received iron-folic acid in last 3 months (15-19)',
#  'Activities excluded during menstrual period: entering the temple',
#  'Activities excluded during menstrual period: getting involved in religious activ',
#  'Activities excluded during menstrual period: touch or cooking food',
#  'Activities excluded during menstrual period: eating with family members',
#  'Activities excluded during menstrual period: staying in the main house',
#  'Activities excluded during menstrual period: touching plants',
#  'Activities excluded during menstrual period: touching other people',
#  'Activities excluded during menstrual period: touching cattle',
#  'Activities excluded during menstrual period: fetch water',
#  'Activities excluded during menstrual period: sleep with husband',
#  'Activities excluded during menstrual period: other',
#  'Activities excluded during menstrual period: Nothing',
#  'Provider of advice/counseling on nutrition: doctor',
#  'Provider of advice/counseling on nutrition: nurse/midwife/ANM',
#  'Provider of advice/counseling on nutrition: health asst./AHW',
#  'Provider of advice/counseling on nutrition: MCHW',
#  'Provider of advice/counseling on nutrition: VHW',
#  'Provider of advice/counseling on nutrition: TBA',
#  'Provider of advice/counseling on nutrition: FCHV',
#  "Provider of advice/counseling on nutrition: mother's group",
#  'Provider of advice/counseling on nutrition: social mobilizer',
#  'Provider of advice/counseling on nutrition: traditional healers',
#  'Provider of advice/counseling on nutrition: others',
#  'Time received advice or counseling: during visit to health facility',
#  'Time received advice or counseling: during FCHV home visit',
#  "Time received advice or counseling: during health mother's group meeting",
#  'Time received advice or counseling: other',
#  'Topic talked about: breastfeeding, not feeding water or other liquids before si',
#  'Topic talked about: introducing soft or solid food when the baby reaches six mon',
#  'Topic talked about: giving a variety of foods',
#  'Topic talked about: how often to feed foods',
#  'Topic talked about: giving animal source food (eggs, milk, meat, fish)',
#  'Topic talked about: giving fruits and vegetable',
#  'Topic talked about: not feeding sugar-sweetened beverages',
#  'Topic talked about: other',
#  'Growth monitoring promotion in this ward (at your closest health facility)',
#  'Partner ever attended school - CS',
#  "Partner's highest grade - CS",
#  "Husband/partner's educational level attained - CS",
#  'Beating justified if wife brings less or no dowry - CS',
#  "Beating justified if wife doesn't follow everyday routine - CS",
#  'Beating justified if wife talks to other men - CS',
#  'Info given during antenatal visit: Babies getting HIV from mother',
#  'Info given during antenatal visit: Things can do to prevent getting HIV',
#  'Info given during antenatal visit: Getting tested for HIV',
#  'Type of nearest healthcare facility',
#  'Heard of breast cancer',
#  'Know woman can do breast self-exam to detect lumps',
#  'Heard of cervical cancer',
#  'Heard any test for cervical cancer',
#  'Ever experienced signs of uterine prolapse',
#  ...]

# %%
dta_files[1] = dta_files[1].rename(columns={'Province': 'Region'})

# %%
common_columns = list(set.intersection(*[set(df.columns) for df in dta_files]))
dta_files = [df[common_columns] for df in dta_files]
clean_data = pd.concat(dta_files, axis=0, ignore_index=True)

# %%
clean_data['Region']
# Out:
# 0        BARMM - Bangsamoro Autonomous Region in Muslim...
# 1        BARMM - Bangsamoro Autonomous Region in Muslim...
# 2        BARMM - Bangsamoro Autonomous Region in Muslim...
# 3        BARMM - Bangsamoro Autonomous Region in Muslim...
# 4        BARMM - Bangsamoro Autonomous Region in Muslim...
#                                ...
# 25308                                         Tboung Khmum
# 25309                                         Tboung Khmum
# 25310                                         Tboung Khmum
# 25311                                         Tboung Khmum
# 25312                                         Tboung Khmum
# Name: Region, Length: 25313, dtype: object

# %% [markdown]
# # Response Variable (y) Calculation

# %%
filename="dash.csv"
clean_data.to_csv(filename, index=False)
